# %%
# Load the Drive helper and mount
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unrar x "/content/drive/MyDrive/tomato_dataset.rar" "/content/drive/MyDrive/tomato_dataset"
# Out:
# UNRAR 6.11 beta 1 freeware      Copyright (c) 1993-2022 Alexander Roshal
#
#
# Extracting from /content/drive/MyDrive/tomato_dataset.rar
#
# Creating    /content/drive/MyDrive/tomato_dataset/tomato_dataset      OK
#   OK
# Creating    /content/drive/MyDrive/tomato_dataset/tomato_dataset/test  OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/drive/MyDrive/tomato_dataset/tomato_dataset/train  OK
#   OK
# ...

# %%
pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 660.4/660.4 kB 6.2 MB/s eta 0:00:00
# ...

# %%
# !yolo task=detect mode=train model=yolov8s.pt data=/content/drive/MyDrive/tomato_dataset/tomato_dataset/dataset.yml epochs=500 batch=16 imgsz=64 patience=100
# Out:
# Ultralytics YOLOv8.0.226 🚀 Python-3.10.12 torch-2.1.0+cu118 CPU (Intel Xeon 2.20GHz)
# ...

# %%
# !yolo task=detect mode=train resume model=/content/runs/detect/train3/weights/last.pt data=/content/drive/MyDrive/tomato_dataset/tomato_dataset/dataset.yml epochs=300 imgsz=64 batch=16 patience = 50
# Out:
# Ultralytics YOLOv8.0.226 🚀 Python-3.10.12 torch-2.1.0+cu118 CPU (Intel Xeon 2.20GHz)
# ...

# %%
cd /content/drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
# !yolo task=detect mode=train resume model=/content/drive/MyDrive/runs/detect/train3/weights/last.pt data=/content/drive/MyDrive/tomato_dataset/tomato_dataset/dataset.yml epochs=300 imgsz=64 batch=16 patience = 50
# Out:
# Ultralytics YOLOv8.0.226 🚀 Python-3.10.12 torch-2.1.0+cu118 CPU (Intel Xeon 2.20GHz)
# ...
